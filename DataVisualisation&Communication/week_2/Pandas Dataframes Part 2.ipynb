# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----------------------------- ---------- 8.4/11.5 MB 47.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 42.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------- ----------------- 7.1/12.6 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 30.2 MB/s eta 0:00:00
# ...

# %%
#!pip install pandas=2.2.3

# %%
import pandas

# %%
type(pandas.DataFrame())
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
type(pd.DataFrame())
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame({
    "Odd numbers": [1, 3, 5, 7, 9],
    "Even numbers": [2, 4, 6, 8, 10],
    "Prime numbers": [2, 3, 5, 7, 11]
})

# %%
df
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
df.shape
# Out:
# (5, 3)

# %%
df.head(2)
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3

# %%
df.tail(2)
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 3            7             8              7
# 4            9            10             11

# %%
df.sample(3)
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 1            3             4              3
# 4            9            10             11
# 2            5             6              5

# %%
df.sample(3).sort_values(by="Odd numbers")
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7

# %%
# locating data based on row/column names
df.loc[:, "Prime numbers"]
# Out:
# 0     2
# 1     3
# 2     5
# 3     7
# 4    11
# Name: Prime numbers, dtype: int64

# %%
# locating data based on row/column names
df.loc[2:, "Prime numbers"]
# Out:
# 2     5
# 3     7
# 4    11
# Name: Prime numbers, dtype: int64

# %%
# locating data based on row/column names
df.loc[2:, ["Prime numbers", "Odd numbers", "Odd numbers"]]
# Out:
#    Prime numbers  Odd numbers  Odd numbers
# 2              5            5            5
# 3              7            7            7
# 4             11            9            9

# %%
# locating data based on row/column names
df.loc[[0, 4, 2], ["Prime numbers", "Odd numbers", "Odd numbers"]]
# Out:
#    Prime numbers  Odd numbers  Odd numbers
# 0              2            1            1
# 4             11            9            9
# 2              5            5            5

# %%
df
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
# locating data based on row/column names
df.iloc[[0, 4, 2], [2, 0, -3]]
# Out:
#    Prime numbers  Odd numbers  Odd numbers
# 0              2            1            1
# 4             11            9            9
# 2              5            5            5

# %%
df["Even numbers"]
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# Name: Even numbers, dtype: int64

# %%
df[["Even numbers", "Odd numbers"]]
# Out:
#    Even numbers  Odd numbers
# 0             2            1
# 1             4            3
# 2             6            5
# 3             8            7
# 4            10            9

# %%
type(df[["Even numbers", "Odd numbers"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Even numbers"])
# Out:
# pandas.core.series.Series

# %%
df["Even numbers"]
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# Name: Even numbers, dtype: int64

# %%
df[ 
    df["Even numbers"] > 5
]
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
(df["Even numbers"] > 5) & (df["Prime numbers"] < 8)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
(df["Even numbers"] > 5) | (df["Prime numbers"] < 8)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
df[ 
(df["Even numbers"] > 5) & (df["Prime numbers"] < 8)
]
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 2            5             6              5
# 3            7             8              7

# %%
df[(df["Even numbers"] > 5) ^ (df["Prime numbers"] < 8)]
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 4            9            10             11

# %%
primeNumbers = df["Prime numbers"]

# %%
primeNumbers < 8
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Prime numbers, dtype: bool

# %%
df
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
df.drop("Odd numbers", axis=1)
# Out:
#    Even numbers  Prime numbers
# 0             2              2
# 1             4              3
# 2             6              5
# 3             8              7
# 4            10             11

# %%
df.shape
# Out:
# (5, 3)

# %%
df
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
df
# Out:
#    Odd numbers  Even numbers  Prime numbers
# 0            1             2              2
# 1            3             4              3
# 2            5             6              5
# 3            7             8              7
# 4            9            10             11

# %%
X = df.drop("Odd numbers", axis=1)
y = df["Odd numbers"]

# %%
X
# Out:
#    Even numbers  Prime numbers
# 0             2              2
# 1             4              3
# 2             6              5
# 3             8              7
# 4            10             11

# %%
y
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# Name: Odd numbers, dtype: int64

# %% [markdown]
# ## Export data
# Export to csv : comma separated values

# %%
df.to_csv("Cool data.csv", index=False)

# %% [markdown]
# ## Import data

# %%
prices_df = pd.read_csv("prices-split-adjusted.csv")

# %%
prices_df.shape
# Out:
# (851264, 7)

# %%
prices_df.columns
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
prices_df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
prices_df.sample(10)
# Out:
#               date symbol        open       close         low        high  \
# 220864  2011-11-11    AES   11.730000   11.780000   11.600000   11.780000
# 354073  2012-12-31    HRB   18.209999   18.570000   18.160000   18.590000
# 197833  2011-09-02    AEP   37.980000   37.980000   37.799999   38.169998
# 563773  2014-09-16    CLX   89.769997   90.180000   89.010002   90.620003
# 605452  2015-01-16    CCL   45.490002   45.459999   44.770000   45.610001
# 120432  2011-01-07      F   18.420000   18.270000   18.080000   18.420000
# 641825  2015-05-04    RTN  105.620003  106.400002  105.239998  107.139999
# 661381  2015-06-30    FLR   53.400002   53.009998   52.720001   53.500000
# 645227  2015-05-13    NWL   40.020000   39.540001   39.529999   40.090000
# 289676  2012-06-13    HES   43.590000   43.130001   42.919998   44.009998
#
#             volume
# 220864   3523700.0
# 354073   2878600.0
# 197833   2356700.0
# 563773    685100.0
# 605452   4589400.0
# 120432  99029500.0
# ...

# %%
prices_df.set_index("date")
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0
# ...           ...         ...         ...         ...         ...        ...
# 2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000   973800.0
# 2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001  1938100.0
# 2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002  1701200.0
# 2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000  1380900.0
# 2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000   705100.0
#
# [851264 rows x 6 columns]

# %%
prices_df
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %%
prices_df.set_index("date", inplace=True)

# %%
prices_df = prices_df.set_index("date")
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0
# ...           ...         ...         ...         ...         ...        ...
# 2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000   973800.0
# 2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001  1938100.0
# 2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002  1701200.0
# 2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000  1380900.0
# 2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000   705100.0
#
# [851264 rows x 6 columns]

# %%
prices_df
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0
# ...           ...         ...         ...         ...         ...        ...
# 2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000   973800.0
# 2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001  1938100.0
# 2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002  1701200.0
# 2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000  1380900.0
# 2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000   705100.0
#
# [851264 rows x 6 columns]

# %%
prices_df.reset_index()
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %%
prices_df.reset_index(inplace=True)

# %%
prices_df
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %%
prices_df.set_index("date", inplace=True)

# %%
prices_df.loc["2016-01-05"]
# Out:
#            symbol        open       close         low        high      volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000   2163600.0
# 2016-01-05      A   40.730000   40.549999   40.340000   40.950001   2587200.0
# 2016-01-05    AAL   41.180000   40.520000   39.950001   41.490002  10514200.0
# 2016-01-05    AAP  152.350006  151.199997  149.889999  153.789993   1127700.0
# 2016-01-05   AAPL  105.750000  102.709999  102.410004  105.849998  55791000.0
# ...           ...         ...         ...         ...         ...         ...
# 2016-01-05    YUM   52.358018   51.782891   51.265279   52.624013   5273400.0
# 2016-01-05    ZBH  102.000000  103.930000  101.599998  104.459999   2227900.0
# 2016-01-05   ZION   26.770000   26.420000   26.240000   26.850000   2653600.0
# 2016-01-05    ZTS   47.509998   48.009998   47.279999   48.099998   3116700.0
# 2016-01-05    AIV   39.779999   40.660000   39.599998   40.840000   1692400.0
#
# [500 rows x 6 columns]

# %%
prices_df[ prices_df["symbol"] == "WLTW" ]
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0
# ...           ...         ...         ...         ...         ...        ...
# 2016-12-23   WLTW  123.089996  124.489998  122.709999  124.660004   361900.0
# 2016-12-27   WLTW  124.570000  124.279999  124.010002  124.900002   382900.0
# 2016-12-28   WLTW  124.300003  122.379997  121.900002  124.300003   429900.0
# 2016-12-29   WLTW  122.449997  122.169998  121.599998  123.070000   216600.0
# 2016-12-30   WLTW  122.589996  122.279999  121.389999  123.559998   466400.0
#
# [251 rows x 6 columns]
